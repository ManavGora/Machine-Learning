# %%
df=pd.read_csv('bikes_data.csv')

# %%
df.head(10)
# Out:
#    Company Country of Origin       Model Number of cc Horsepower   Torque  \
# 0  Aprilia             Italy      RS 660          659     100 hp    67 Nm
# 1  Aprilia             Italy   Tuono 660          659     100 hp    67 Nm
# 2  Aprilia             Italy      RS 125        124.9      15 hp    12 Nm
# 3  Aprilia             Italy  Shiver 900          896      95 hp    90 Nm
# 4  Aprilia             Italy  Tuono 1100         1077     175 hp   121 Nm
# 5  Benelli             Italy     TNT 125          125      11 hp  10.8 Nm
# 6  Benelli             Italy     TNT 250          250      27 hp  21.2 Nm
# 7  Benelli             Italy     TNT 300          300      39 hp  26.5 Nm
# 8  Benelli             Italy    TNT 600i          600      85 hp  54.6 Nm
# 9  Benelli             Italy     TNT 899          899     116 hp  86.3 Nm
#
#       Transmission Type Drivetrain  Number of Seating Price (in INR)  Year  \
# 0  6-speed quickshifter      Chain                  2  INR 10,99,000  2021
# ...

# %%
df.shape
# Out:
# (362, 15)

# %% [markdown]
# # Univariate Analysis

# %%
df_benelli=df.loc[df['Company']=='Benelli']

# %%
print(df_ducati)
# Out:
#    Company Country of Origin           Model Number of cc Horsepower  \
# 51  Ducati             Italy     Panigale V4         1103     221 hp
# 52  Ducati             Italy          Diavel         1262   159.6 hp
# 53  Ducati             Italy   Scrambler 800          803      73 hp
# 54  Ducati             Italy         Monster          937     111 hp
# 55  Ducati             Italy  Multistrada V4         1158     168 hp
#
#        Torque          Transmission Type Drivetrain  Number of Seating  \
# 51  124 lb-ft  6-speed sequential manual      Chain                  1
# 52   93 lb-ft          6-speed automatic       Belt                  1
# 53   47 lb-ft             6-speed manual      Chain                  2
# 54   69 lb-ft             6-speed manual      Chain                  1
# 55   93 lb-ft  6-speed sequential manual      Shaft                  2
#
#    Price (in INR)  Year      Looks  Body Type Engine Type Number of Cylinders
# ...

# %%
df_bmw=df.loc[df['Company']=='BMW']

# %%
df_ducati=df.loc[df['Company']=='Ducati']

# %%
plt.plot(df_benelli['Number of cc'],np.zeros_like(df_benelli['Number of cc']),'o')
plt.plot(df_bmw['Number of cc'],np.zeros_like(df_bmw['Number of cc']),'o')
plt.plot(df_ducati['Number of cc'],np.zeros_like(df_ducati['Number of cc']),'o')
plt.xlabel('no. of cc')
plt.show()

# %% [markdown]
# # Bivariate Analysis

# %%
sns.FacetGrid(df,hue='Number of Cylinders',height=5).map(plt.scatter,"Drivetrain","Body Type").add_legend();
plt.show()

# %% [markdown]
# # Multivariate Analysis

# %%
sns.pairplot(df,hue='Number of Cylinders',height=3)
